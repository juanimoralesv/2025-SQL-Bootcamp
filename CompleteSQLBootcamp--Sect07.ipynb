# %% [markdown]
# # S07 - Assessment Test 2

# %% [markdown]
# ## Libraries

# %%
import os
import sqlite3 as sql
import pandas as pd

# %% [markdown]
# ## Functions

# %%
# Function taking a SQL query file to format its text for Jupyter Notebook
def query_text_format(path, file):
    # Change directory
    try:
        os.chdir(path)
    except FileNotFoundError:
        print(f"El directorio {path} no se encontró.")
        return
    
    # Read file
    try:
        with open(file, 'r') as f:
            query_log = f.read()
    except FileNotFoundError:
        print(f"El archivo {file} no se encontró.")
        return
    
    # Text formatting
    # Removal of SQL comment closing
    query_log = query_log.replace(' */', '')
    # Split into lines
    query_log_lines = query_log.split('\n')
    
    # Enumerated iteration over all file lines
    for i, line in enumerate(query_log_lines):
        query_log_lines[i] = line.strip()
        
        # Replacement of SQL comment opening
        if query_log_lines[i][:2] == '/*':
            # Search two integers to detect lesson start
            double_int = []            
            for char in line[3:5]:
                try:
                    if isinstance(int(char), int):
                        double_int.append(1)
                except:
                    pass
            
            # If two integers found, replacement according to lesson start
            if len(double_int) == 2:
                query_log_lines[i] = query_log_lines[i].replace('/*', '###')
            # If a letter, replacement according to assessment exercise start
            elif query_log_lines[i][3].isalpha() and query_log_lines[i][4] == '.':
                query_log_lines[i] = query_log_lines[i].replace('/*', '####')
            # Remaining SQL comments are Python comments, too
            else:
                query_log_lines[i] = query_log_lines[i].replace('/*', '#')
        
        # If line not empty
        elif line != '':
            query_log_lines[i] = '\t' + query_log_lines[i] + ' \\'
        
        # Rest of cases (potential)
        else:
            pass
        
    return '\n'.join(query_log_lines)

# %%
# Function taking the SQL queries and building Python code to execute them
def build_python_queries(text):
    # Split into lines
    query_lines = text.split('\n')
    
    # Build SQL queries in Python
    resulting_text = []
    flg_first_sql_line = True
    
    for i, line in enumerate(query_lines):
        # Empty line
        if line == '':
            resulting_text.append(line)
        # Line starting with tab
        elif query_lines[i][0] == '\t':
            # First query line
            if flg_first_sql_line:
                # First query line in one line query
                if (i + 1 <= len(query_lines) - 1) and ((query_lines[i + 1] == '') or ((query_lines[i + 1][0] != '') and (query_lines[i + 1][0] == '#'))):
                    resulting_text.append('query = " \\')
                    resulting_text.append(line)
                    resulting_text.append('\t"')
                    resulting_text.append('execute_query(query, conn)')
                # First query line in multiple lines query
                else:
                    resulting_text.append('query = " \\')
                    resulting_text.append(line)
                    flg_first_sql_line = False
            # Second, or other, query line
            else:
                # Last query line
                if (i + 1 <= len(query_lines) - 1) and ((query_lines[i + 1] == '') or ((query_lines[i + 1][0] != '') and (query_lines[i + 1][0] == '#'))):
                    resulting_text.append(line)
                    resulting_text.append('\t"')
                    resulting_text.append('execute_query(query, conn)')
                    flg_first_sql_line = True
                # Query line, absolute last one
                elif i == len(query_lines) - 1:
                    resulting_text.append(line)
                    resulting_text.append('\t"')
                    resulting_text.append('execute_query(query, conn)')
                # Query lines that are not first nor last
                else:
                    resulting_text.append(line)
        # Other lines
        else:
            resulting_text.append(line)
    
    return '\n'.join(resulting_text)

# %%
# Function taking the SQL query text and executing it
def execute_query(query_text, connection):
    # DataFrame from query
    results_df = pd.read_sql_query(
        query_text,
        connection
    )

    print(results_df)

# %% [markdown]
# ## Settings

# %%
# Limit removal for showing pandas.DataFrames' columns
pd.set_option('display.max_columns', None)
# Limit removal for showing pandas.DataFrames' rows
pd.set_option('display.max_rows', None)
# Modification of console with for displaying
pd.set_option('display.width', 8000)

# %% [markdown]
# ## SQL Query Formatting

# %%
# First formatting
path = 'G:\\15_Estudio\\Udemy\\SQL - Portilla Complete Bootcamp'
file = 'UDM-SQL-BTCMP--007.sql'

first_pass = query_text_format(path, file)
print(first_pass)
# Out:
# ### 56. Setting up New Database for Assessment Exercises
# # Explore the tables
# 	SELECT * \
# 	FROM cd.bookings; \
#
# 	SELECT * \
# 	FROM cd.facilities; \
#
# 	SELECT * \
# 	FROM cd.members; \
# # All tables seem ok after having setted the bin path
#
#
# ### 57. Assessment Test 2
# ### 58. Solutions to Assessment Test 2
# #### a. All the information from the facilities table
# 	SELECT * \
# 	FROM cd.facilities; \
#
# #### b. Retrieve a list of only facility names and costs to members
# 	SELECT name, membercost \
# 	FROM cd.facilities; \
#
# #### c. Retrieve a list of facility names that charge a fee to members
# 	SELECT * \
# 	FROM cd.facilities \
# 	WHERE membercost > 0; \
#
# #### d. Retrieve a list of facility names that charge a fee to members
# # and that fee is less than 1/50th of the monthly maintenance cost.
# # Return the facid, facility name, member cost, and monthly
# # maintenance of the facilities in question
# 	SELECT facid, name, membercost, monthlymaintenance \
# ...

# %%
# Final formatting
working_text = build_python_queries(first_pass)
# Schema name removal
working_text = working_text.replace('cd.', '')
print(working_text)
# Out:
# ### 56. Setting up New Database for Assessment Exercises
# # Explore the tables
# query = " \
# 	SELECT * \
# 	FROM bookings; \
# 	"
# execute_query(query, conn)
#
# query = " \
# 	SELECT * \
# 	FROM facilities; \
# 	"
# execute_query(query, conn)
#
# query = " \
# 	SELECT * \
# 	FROM members; \
# 	"
# execute_query(query, conn)
# # All tables seem ok after having setted the bin path
#
#
# ### 57. Assessment Test 2
# ### 58. Solutions to Assessment Test 2
# #### a. All the information from the facilities table
# query = " \
# 	SELECT * \
# 	FROM facilities; \
# 	"
# execute_query(query, conn)
#
# #### b. Retrieve a list of only facility names and costs to members
# query = " \
# 	SELECT name, membercost \
# 	FROM facilities; \
# 	"
# execute_query(query, conn)
#
# #### c. Retrieve a list of facility names that charge a fee to members
# query = " \
# 	SELECT * \
# 	FROM facilities \
# 	WHERE membercost > 0; \
# 	"
# execute_query(query, conn)
#
# ...

# %% [markdown]
# This text will be used to create the whole of the Practice section in this notebook.

# %% [markdown]
# ## Practice

# %% [markdown]
# ### Connection with Data Base

# %%
# Connection and cursor
conn = sql.connect('G:\\15_Estudio\\Udemy\\SQL - Portilla Complete Bootcamp\\exercises.db')
cur = conn.cursor()

# %%
# Iterate over csv files and load into SQLite
csv_folder = 'G:\\15_Estudio\\Udemy\\SQL - Portilla Complete Bootcamp\\Exercises_DB'

for csv_file in os.listdir(csv_folder):
    if csv_file.endswith('.csv'):
        table_name = csv_file[:-4]  # Nombre de tabla
        
        # CSV into DataFrame
        try:
            # Caso "film.csv", tabulación
            if csv_file == 'film.csv':
                df = pd.read_csv(
                    os.path.join(csv_folder, csv_file),
                    delimiter = '\t'
                )
            else:
                df = pd.read_csv(
                    os.path.join(csv_folder, csv_file)
                )
            
            # Importar DataFrame a SQLite
            df.to_sql(
                table_name,
                conn,
                if_exists = 'replace',
                index = False
            )
            print(f"Archivo {csv_file} importado correctamente.")
        except Exception as e:
            print(f"Error al procesar {csv_file}: {e}")
# Out:
# Archivo bookings.csv importado correctamente.
# Archivo facilities.csv importado correctamente.
# Archivo members.csv importado correctamente.

# %% [markdown]
# ### 56. Setting up New Database for Assessment Exercises

# %%
# Explore the tables
query = " \
	SELECT * \
	FROM bookings; \
	"
execute_query(query, conn)
# Out:
#       bookid  facid  memid            starttime  slots
# 0          0      3      1  2012-07-03 11:00:00      2
# 1          1      4      1  2012-07-03 08:00:00      2
# 2          2      6      0  2012-07-03 18:00:00      2
# 3          3      7      1  2012-07-03 19:00:00      2
# 4          4      8      1  2012-07-03 10:00:00      1
# 5          5      8      1  2012-07-03 15:00:00      1
# 6          6      0      2  2012-07-04 09:00:00      3
# 7          7      0      2  2012-07-04 15:00:00      3
# 8          8      4      3  2012-07-04 13:30:00      2
# 9          9      4      0  2012-07-04 15:00:00      2
# 10        10      4      0  2012-07-04 17:30:00      2
# 11        11      6      0  2012-07-04 12:30:00      2
# 12        12      6      0  2012-07-04 14:00:00      2
# 13        13      6      1  2012-07-04 15:30:00      2
# 14        14      7      2  2012-07-04 14:00:00      2
# 15        15      8      2  2012-07-04 12:00:00      1
# ...

# %%
query = " \
	SELECT * \
	FROM facilities; \
	"
execute_query(query, conn)
# Out:
#    facid             name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0   Tennis Court 1         5.0       25.0          10000                 200
# 1      1   Tennis Court 2         5.0       25.0           8000                 200
# 2      2  Badminton Court         0.0       15.5           4000                  50
# 3      3     Table Tennis         0.0        5.0            320                  10
# 4      4   Massage Room 1        35.0       80.0           4000                3000
# 5      5   Massage Room 2        35.0       80.0           4000                3000
# 6      6     Squash Court         3.5       17.5           5000                  80
# 7      7    Snooker Table         0.0        5.0            450                  15
# 8      8       Pool Table         0.0        5.0            400                  15

# %%
query = " \
	SELECT * \
	FROM members; \
	"
execute_query(query, conn)
# All tables seem ok after having setted the bin path
# Out:
#     memid            surname  firstname                                  address  zipcode       telephone  recommendedby             joindate
# 0       0              GUEST      GUEST                                    GUEST        0  (000) 000-0000            NaN  2012-07-01 00:00:00
# 1       1              Smith     Darren               8 Bloomsbury Close, Boston     4321    555-555-5555            NaN  2012-07-02 12:02:05
# 2       2              Smith      Tracy             8 Bloomsbury Close, New York     4321    555-555-5555            NaN  2012-07-02 12:08:23
# 3       3             Rownam        Tim                   23 Highway Way, Boston    23423  (844) 693-0723            NaN  2012-07-03 09:32:15
# 4       4           Joplette     Janice               20 Crossing Road, New York      234  (833) 942-4710            1.0  2012-07-03 10:25:05
# ...

# %% [markdown]
# ### 57. Assessment Test 2

# %% [markdown]
# ### 58. Solutions to Assessment Test 2

# %% [markdown]
# #### a. All the information from the facilities table

# %%
query = " \
	SELECT * \
	FROM facilities; \
	"
execute_query(query, conn)
# Out:
#    facid             name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0   Tennis Court 1         5.0       25.0          10000                 200
# 1      1   Tennis Court 2         5.0       25.0           8000                 200
# 2      2  Badminton Court         0.0       15.5           4000                  50
# 3      3     Table Tennis         0.0        5.0            320                  10
# 4      4   Massage Room 1        35.0       80.0           4000                3000
# 5      5   Massage Room 2        35.0       80.0           4000                3000
# 6      6     Squash Court         3.5       17.5           5000                  80
# 7      7    Snooker Table         0.0        5.0            450                  15
# 8      8       Pool Table         0.0        5.0            400                  15

# %% [markdown]
# #### b. Retrieve a list of only facility names and costs to members

# %%
query = " \
	SELECT name, membercost \
	FROM facilities; \
	"
execute_query(query, conn)
# Out:
#               name  membercost
# 0   Tennis Court 1         5.0
# 1   Tennis Court 2         5.0
# 2  Badminton Court         0.0
# 3     Table Tennis         0.0
# 4   Massage Room 1        35.0
# 5   Massage Room 2        35.0
# 6     Squash Court         3.5
# 7    Snooker Table         0.0
# 8       Pool Table         0.0

# %% [markdown]
# #### c. Retrieve a list of facility names that charge a fee to members

# %%
query = " \
	SELECT * \
	FROM facilities \
	WHERE membercost > 0; \
	"
execute_query(query, conn)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0  Tennis Court 1         5.0       25.0          10000                 200
# 1      1  Tennis Court 2         5.0       25.0           8000                 200
# 2      4  Massage Room 1        35.0       80.0           4000                3000
# 3      5  Massage Room 2        35.0       80.0           4000                3000
# 4      6    Squash Court         3.5       17.5           5000                  80

# %% [markdown]
# #### d. Retrieve a list of facility names that charge a fee to members and that fee is less than 1/50th of the monthly maintenance cost. Return the facid, facility name, member cost, and monthly maintenance of the facilities in question

# %%
query = " \
	SELECT facid, name, membercost, monthlymaintenance \
	FROM facilities \
	WHERE membercost > 0 \
	AND membercost < monthlymaintenance / 50; \
	"
execute_query(query, conn)
# From 58. NOTE: use 50.0 to get decimals in result
# Out:
#    facid            name  membercost  monthlymaintenance
# 0      4  Massage Room 1        35.0                3000
# 1      5  Massage Room 2        35.0                3000

# %% [markdown]
# #### e. Produce a list of all facilities with the word 'Tennis' in their name

# %%
query = " \
	SELECT * \
	FROM facilities \
	WHERE name LIKE '%Tennis%'; \
	"
execute_query(query, conn)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0  Tennis Court 1         5.0       25.0          10000                 200
# 1      1  Tennis Court 2         5.0       25.0           8000                 200
# 2      3    Table Tennis         0.0        5.0            320                  10

# %% [markdown]
# #### f. Retrieve the details of facilities with ID 1 and 5.

# %%
# Try to do it without using the OR operator
query = " \
	SELECT * \
	FROM facilities \
	WHERE facid IN (1, 5); \
	"
execute_query(query, conn)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      1  Tennis Court 2         5.0       25.0           8000                 200
# 1      5  Massage Room 2        35.0       80.0           4000                3000

# %%
# From 58., using OR
query = " \
	SELECT * FROM facilities WHERE facid = 1 OR facid = 5; \
	"
execute_query(query, conn)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      1  Tennis Court 2         5.0       25.0           8000                 200
# 1      5  Massage Room 2        35.0       80.0           4000                3000

# %% [markdown]
# #### g. Produce a list of members who joined after the start of September 2012. Return the memid, surname, firstname, and joindate of the members in question.

# %%
query = " \
	SELECT memid, surname, firstname, joindate \
	FROM members \
	WHERE joindate > '2012-09-01'; \
	"
execute_query(query, conn)
# Out:
#    memid            surname  firstname             joindate
# 0     24             Sarwin  Ramnaresh  2012-09-01 08:44:42
# 1     26              Jones    Douglas  2012-09-02 18:43:05
# 2     27             Rumney  Henrietta  2012-09-05 08:42:35
# 3     28            Farrell      David  2012-09-15 08:22:05
# 4     29  Worthington-Smyth      Henry  2012-09-17 12:27:15
# 5     30            Purview  Millicent  2012-09-18 19:04:01
# 6     33         Tupperware   Hyacinth  2012-09-18 19:32:05
# 7     35               Hunt       John  2012-09-19 11:32:45
# 8     36            Crumpet      Erica  2012-09-22 08:36:38
# 9     37              Smith     Darren  2012-09-26 18:08:45

# %% [markdown]
# #### h. Produce an ordered list of the first 10 surnames in the members table? The list must not contain duplicates.

# %%
query = " \
	SELECT DISTINCT(surname) \
	FROM members \
	ORDER BY surname ASC \
	LIMIT 10; \
	"
execute_query(query, conn)
# Out:
#    surname
# 0    Bader
# 1    Baker
# 2   Boothe
# 3  Butters
# 4   Coplin
# 5  Crumpet
# 6     Dare
# 7  Farrell
# 8    GUEST
# 9  Genting

# %% [markdown]
# #### i. Get the signup date of your last member

# %%
# Exploration
query = " \
	SELECT * \
	FROM members; \
	"
execute_query(query, conn)
# Out:
#     memid            surname  firstname                                  address  zipcode       telephone  recommendedby             joindate
# 0       0              GUEST      GUEST                                    GUEST        0  (000) 000-0000            NaN  2012-07-01 00:00:00
# 1       1              Smith     Darren               8 Bloomsbury Close, Boston     4321    555-555-5555            NaN  2012-07-02 12:02:05
# 2       2              Smith      Tracy             8 Bloomsbury Close, New York     4321    555-555-5555            NaN  2012-07-02 12:08:23
# 3       3             Rownam        Tim                   23 Highway Way, Boston    23423  (844) 693-0723            NaN  2012-07-03 09:32:15
# 4       4           Joplette     Janice               20 Crossing Road, New York      234  (833) 942-4710            1.0  2012-07-03 10:25:05
# ...

# %%
# Solution
query = " \
	SELECT MAX(joindate) \
	FROM members; \
	"
execute_query(query, conn)
# Out:
#          MAX(joindate)
# 0  2012-09-26 18:08:45

# %% [markdown]
# #### j. Produce a count of the number of facilities that have a cost to guests of 10 or more.

# %%
# Exploration
query = " \
	SELECT * \
	FROM facilities; \
	"
execute_query(query, conn)
# Out:
#    facid             name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0   Tennis Court 1         5.0       25.0          10000                 200
# 1      1   Tennis Court 2         5.0       25.0           8000                 200
# 2      2  Badminton Court         0.0       15.5           4000                  50
# 3      3     Table Tennis         0.0        5.0            320                  10
# 4      4   Massage Room 1        35.0       80.0           4000                3000
# 5      5   Massage Room 2        35.0       80.0           4000                3000
# 6      6     Squash Court         3.5       17.5           5000                  80
# 7      7    Snooker Table         0.0        5.0            450                  15
# 8      8       Pool Table         0.0        5.0            400                  15

# %%
# Solution
query = " \
	SELECT COUNT(facid) AS fac_gcost_10 \
	FROM facilities \
	WHERE guestcost >= 10; \
	"
execute_query(query, conn)
# Out:
#    fac_gcost_10
# 0             6

# %% [markdown]
# #### k. (11) Produce a list of the total number of slots booked per facility in the month of September 2012. Produce an output table consisting of facility id and slots, sorted by the number of slots.

# %%
# Exploration
query = " \
	SELECT * \
	FROM facilities; \
	"
execute_query(query, conn)
# Out:
#    facid             name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0   Tennis Court 1         5.0       25.0          10000                 200
# 1      1   Tennis Court 2         5.0       25.0           8000                 200
# 2      2  Badminton Court         0.0       15.5           4000                  50
# 3      3     Table Tennis         0.0        5.0            320                  10
# 4      4   Massage Room 1        35.0       80.0           4000                3000
# 5      5   Massage Room 2        35.0       80.0           4000                3000
# 6      6     Squash Court         3.5       17.5           5000                  80
# 7      7    Snooker Table         0.0        5.0            450                  15
# 8      8       Pool Table         0.0        5.0            400                  15

# %%
query = " \
	SELECT * \
	FROM bookings; \
	"
execute_query(query, conn)
# Out:
#       bookid  facid  memid            starttime  slots
# 0          0      3      1  2012-07-03 11:00:00      2
# 1          1      4      1  2012-07-03 08:00:00      2
# 2          2      6      0  2012-07-03 18:00:00      2
# 3          3      7      1  2012-07-03 19:00:00      2
# 4          4      8      1  2012-07-03 10:00:00      1
# 5          5      8      1  2012-07-03 15:00:00      1
# 6          6      0      2  2012-07-04 09:00:00      3
# 7          7      0      2  2012-07-04 15:00:00      3
# 8          8      4      3  2012-07-04 13:30:00      2
# 9          9      4      0  2012-07-04 15:00:00      2
# 10        10      4      0  2012-07-04 17:30:00      2
# 11        11      6      0  2012-07-04 12:30:00      2
# 12        12      6      0  2012-07-04 14:00:00      2
# 13        13      6      1  2012-07-04 15:30:00      2
# 14        14      7      2  2012-07-04 14:00:00      2
# 15        15      8      2  2012-07-04 12:00:00      1
# ...

# %%
query = " \
    SELECT fac.facid AS fac_id, \
    SUM(boo.slots) AS total_slots \
    FROM facilities AS fac \
    JOIN bookings AS boo \
    ON fac.facid = boo.facid \
    WHERE strftime('%Y', starttime) = '2012' \
    AND strftime('%m', starttime) = '09' \
    GROUP BY fac_id \
    ORDER BY total_slots; \
    "
execute_query(query, conn)
# Query in Postgre was:
#	SELECT fac.facid AS fac_id, \
#	SUM(boo.slots) AS total_slots \
#	FROM facilities AS fac \
#	JOIN bookings AS boo \
#	ON fac.facid = boo.facid \
#	WHERE EXTRACT(YEAR FROM starttime) = '2012' \
#	AND EXTRACT(MONTH FROM starttime) = '9' \
#	GROUP BY fac_id \
#	ORDER BY total_slots; \
# Out:
#    fac_id  total_slots
# 0       5          122
# 1       3          422
# 2       7          426
# 3       8          471
# 4       6          540
# 5       2          570
# 6       1          588
# 7       0          591
# 8       4          648

# %%
# Inspired from 58., simpler version
query = " \
    SELECT facid, SUM(slots) AS total_slots \
    FROM bookings \
    WHERE strftime('%Y', starttime) = '2012' \
    AND strftime('%m', starttime) = '09' \
    GROUP BY facid \
    ORDER BY total_slots; \
    "
execute_query(query, conn)
# Query in Postgre was:
#	SELECT facid, SUM(slots) AS total_slots \
#	FROM bookings \
#	WHERE EXTRACT(YEAR FROM starttime) = '2012' \
#	AND EXTRACT(MONTH FROM starttime) = '9' \
#	GROUP BY facid \
#	ORDER BY SUM(slots); \
# Out:
#    facid  total_slots
# 0      5          122
# 1      3          422
# 2      7          426
# 3      8          471
# 4      6          540
# 5      2          570
# 6      1          588
# 7      0          591
# 8      4          648

# %% [markdown]
# #### l. (12) Produce a list of facilities with more than 1000 slots booked. Produce an output table consisting of facility id and total slots, sorted by facility id.

# %%
query = " \
	SELECT facid, SUM(slots) AS total_slots \
	FROM bookings \
	GROUP BY facid \
	HAVING SUM(slots) > 1000 \
	ORDER BY facid ASC; \
	"
execute_query(query, conn)
# Out:
#    facid  total_slots
# 0      0         1320
# 1      1         1278
# 2      2         1209
# 3      4         1404
# 4      6         1104

# %% [markdown]
# #### m. (13) Produce a list of the start times for bookings for tennis courts, for the date '2012-09-21'. Return a list of start time and facility name pairings, ordered by the time.

# %%
# Exploration
query = " \
	SELECT * \
	FROM bookings \
	LIMIT 1; \
	"
execute_query(query, conn)
# Out:
#    bookid  facid  memid            starttime  slots
# 0       0      3      1  2012-07-03 11:00:00      2

# %%
query = " \
	SELECT * \
	FROM facilities \
	LIMIT 1; \
	"
execute_query(query, conn)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  monthlymaintenance
# 0      0  Tennis Court 1         5.0       25.0          10000                 200

# %%
# Solution
query = " \
    SELECT fac.name, boo.starttime \
    FROM facilities AS fac \
    JOIN bookings AS boo \
    ON fac.facid = boo.facid \
    WHERE fac.name LIKE '%Tennis%' \
    AND fac.name LIKE '%Court%' \
    AND strftime('%Y-%m-%d', boo.starttime) = '2012-09-21' \
    ORDER BY boo.starttime ASC; \
    "
execute_query(query, conn)
# In Postgre it was:
#	SELECT fac.name, boo.starttime \
#	FROM facilities AS fac \
#	JOIN bookings AS boo \
#	ON fac.facid = boo.facid \
#	WHERE fac.name LIKE '%Tennis%' \
#	AND fac.name LIKE '%Court%' \
#	AND TO_CHAR(boo.starttime, 'yyyy-mm-dd') = '2012-09-21' \
#	ORDER BY boo.starttime ASC; \
# Out:
#               name            starttime
# 0   Tennis Court 1  2012-09-21 08:00:00
# 1   Tennis Court 2  2012-09-21 08:00:00
# 2   Tennis Court 1  2012-09-21 09:30:00
# 3   Tennis Court 2  2012-09-21 10:00:00
# 4   Tennis Court 2  2012-09-21 11:30:00
# 5   Tennis Court 1  2012-09-21 12:00:00
# 6   Tennis Court 1  2012-09-21 13:30:00
# 7   Tennis Court 2  2012-09-21 14:00:00
# 8   Tennis Court 1  2012-09-21 15:30:00
# 9   Tennis Court 2  2012-09-21 16:00:00
# 10  Tennis Court 1  2012-09-21 17:00:00
# 11  Tennis Court 2  2012-09-21 18:00:00

# %% [markdown]
# #### n. Produce a list of the start times for bookings by members named 'David Farrell'

# %%
# Exploration
query = " \
	SELECT * \
	FROM members \
	LIMIT 1; \
	"
execute_query(query, conn)
# Out:
#    memid surname firstname address  zipcode       telephone recommendedby             joindate
# 0      0   GUEST     GUEST   GUEST        0  (000) 000-0000          None  2012-07-01 00:00:00

# %%
query = " \
	SELECT * \
	FROM bookings \
	LIMIT 1; \
	"
execute_query(query, conn)
# Out:
#    bookid  facid  memid            starttime  slots
# 0       0      3      1  2012-07-03 11:00:00      2

# %%
# Solution
query = " \
	SELECT mem.firstname || ' ' || mem.surname AS member_name, boo.starttime \
	FROM members AS mem \
	JOIN bookings AS boo \
	ON mem.memid = boo.memid \
	WHERE mem.firstname = 'David' \
	AND mem.surname = 'Farrell'; \
	"
execute_query(query, conn)
# Out:
#       member_name            starttime
# 0   David Farrell  2012-09-18 09:00:00
# 1   David Farrell  2012-09-18 13:30:00
# 2   David Farrell  2012-09-18 17:30:00
# 3   David Farrell  2012-09-18 20:00:00
# 4   David Farrell  2012-09-19 09:30:00
# 5   David Farrell  2012-09-19 12:00:00
# 6   David Farrell  2012-09-19 15:00:00
# 7   David Farrell  2012-09-20 11:30:00
# 8   David Farrell  2012-09-20 14:00:00
# 9   David Farrell  2012-09-20 15:30:00
# 10  David Farrell  2012-09-21 10:30:00
# 11  David Farrell  2012-09-21 14:00:00
# 12  David Farrell  2012-09-22 08:30:00
# 13  David Farrell  2012-09-22 17:00:00
# 14  David Farrell  2012-09-23 08:30:00
# 15  David Farrell  2012-09-23 17:30:00
# 16  David Farrell  2012-09-23 19:00:00
# 17  David Farrell  2012-09-24 08:00:00
# 18  David Farrell  2012-09-24 12:30:00
# 19  David Farrell  2012-09-24 16:30:00
# 20  David Farrell  2012-09-25 15:30:00
# 21  David Farrell  2012-09-25 17:00:00
# 22  David Farrell  2012-09-26 13:00:00
# ...
